# %% [markdown]
# ## Atlantic Trading Volatility Summary

# %% [markdown]
# ##### Project configuration

# %%
import project_path

# %% [markdown]
# ##### Initialise Project Modules

# %%
#backend modules
from configuration import ConfigurationFactory
from service.registry import RegistryManager
from service.log import LogService
from model.dbmodel import DatabaseService, ShortEndDatabaseManager
from analysis.analytics import DataAnalyticsService
from matplotlib.backends.backend_gtk3agg import FigureCanvasGTK3Agg as FigureCanvas

#front end modules
# %matplotlib inline
from model.payload import Payload, PayloadProcessor, payloads
from graph.graph import Lineplot, Scatterplot, Heatplot

# %%
#configuration
config = ConfigurationFactory.create_config()

#initialise all of the services
log_serv = LogService(config["system"]["log"])
db_serv = DatabaseService(config["system"]["db"])
analytics = DataAnalyticsService()

#start all services
log_serv.start()
db_serv.start()
analytics.start()
# Out:
# 20190605 12:36:59.842917 - DEBUG : postgresql+psycopg2://postgres:Atlantic11@localhost:5432/HistoricalVol connection string created
# 20190605 12:37:00.017821 - DEBUG : Connection to the database HistoricalVol successful
# 20190605 12:37:00.261142 - DEBUG : creating tables into database HistoricalVol
# 20190605 12:37:00.269242 - DEBUG : establishing connection to the database
# 20190605 12:37:00.270266 - DEBUG : connection to the database complete

# %% [markdown]
# ##### Process analysis payloads and create datamodel

# %%
#process payload and create datamodel (temp)
datamodel = {}
for plid, pl in payloads.items():
    PayloadProcessor(pl, db_serv.db)
    datamodel[plid] = analytics.gen_plot_datamodel(payloads[plid])
    
stl_hp = analytics.gen_heatplot_matrix(payloads["p1"])
ebor_hp = analytics.gen_heatplot_matrix(payloads["p4"])

# %% [markdown]
# ### Short Sterling (1Y) Vol Summary

# %% [markdown]
# Commentary:
#
# - Over the past year this is the first time we are seeing vol and futures at these levels
# - Implied vol currently in line with 1Y mean realized vol
# - 56% of the realized vol in M Q2 currently below the implied level (most expensive on the heatmap)
# - 36% of the realized vol in L Q2 currently below the implied level (least expensive on heatmap)

# %% [markdown]
# ##### L Q2 (1Y)

# %%
#Lineplot
line = Lineplot(datamodel["p1"])
display(line.figure)

# %%
#Scatterplot
scat = Scatterplot(datamodel["p1"])
display(scat.figure)

#Current bucket (futures range: 99.18-99.21 | interp range: 21-24)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### M Q2 (1Y)

# %%
#Lineplot
line = Lineplot(datamodel["p2"])
display(line.figure)

# %%
#Scatterplot
scat = Scatterplot(datamodel["p2"])
display(scat.figure)

#Current bucket (futures range: 99.18-99.21 | interp range: 48-52)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### M2 Q2 (1Y)

# %%
#Lineplot
line = Lineplot(datamodel["p3"])
display(line.figure)

# %%
#Scatterplot
scat = Scatterplot(datamodel["p3"])
display(scat.figure)

#Current bucket (futures range: 99.12-99.19 | interp range: 60-65)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Short Sterling Vol P-Scores (1Y)

# %%
#Heatplot
heat = Heatplot(stl_hp)
display(heat.figure)

# %% [markdown]
# ### Euribor (1Y) Vol Summary

# %% [markdown]
# Commentary:
#
# - Over the past year this is the first time we are seeing vol and futures at these levels in I, K (huge bear flatten)
# - K2 has previously been up at these levels and has sustained them for some time
# - implied vol across the curve avg 4 interps lower than 1Y mean realized vol
# - 60% of the realized vol in K Q1 currently below the implied level (most expensive on the heatmap)
# - 9% of the 1Y realized vol in I Q1 currently below the implied level (least expensive on heatmap)

# %% [markdown]
# ##### I Q2 (1Y)

# %%
#Lineplot
line = Lineplot(datamodel["p4"])
display(line.figure)

# %%
#Scatterplot
scat = Scatterplot(datamodel["p4"])
display(scat.figure)

#Current bucket (futures range: 100.34-100.35 | interp range: 13-14)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### K Q2 (1Y)

# %%
#Lineplot
line = Lineplot(datamodel["p5"])
display(line.figure)

# %%
#Scatterplot
scat = Scatterplot(datamodel["p5"])
display(scat.figure)

#Current bucket (futures range: 100.32-100.36 | interp range: 19-20)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ##### K2 Q2 (1Y)

# %%
#Lineplot
line = Lineplot(datamodel["p6"])
display(line.figure)

# %%
#Scatterplot
scat = Scatterplot(datamodel["p6"])
display(scat.figure)

#Current bucket (futures range: 100.16-100.24 | interp range: 32-34)
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# #### Euribor Vol P-Scores (1Y)

# %%
#Heatplot
heat = Heatplot(ebor_hp)
display(heat.figure)

# %% [markdown]
# Copyright : 2018 Atlantic Trading London Ltd. All rights reserved.
#
# Date of Creation : 4 June 2019
#
# Author : Nilesh Ramnarain
